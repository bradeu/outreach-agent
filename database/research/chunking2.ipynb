# %%
import os
from getpass import getpass
from semantic_router.encoders import OpenAIEncoder
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or getpass(
    "OpenAI API key: "
)

encoder = OpenAIEncoder(name="text-embedding-3-small")

# %%
from semantic_chunkers import StatisticalChunker

chunker = StatisticalChunker(encoder=encoder)

# %%
chunks = chunker(docs=["The first major breakthrough in AI came with the development of symbolic reasoning in the late 1950s. Researchers like Herbert Simon and Allen Newell developed programs capable of solving algebra problems, proving theorems, and even playing chess. However, the enthusiasm was short-lived as researchers encountered the limitations of early systems. By the 1970s, funding for AI research declined due to unrealistic expectations and the inability of early AI to handle complex tasks effectively."])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]2024-10-20 23:40:14 ERROR semantic_router.utils.logger Exception occurred
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_router/encoders/openai.py", line 117, in __call__
#     embeds = self.client.embeddings.create(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/resources/embeddings.py", line 124, in create
#     return self._post(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1277, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 954, in request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1043, in _request
#     return self._retry_request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1092, in _retry_request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1043, in _request
#     return self._retry_request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1092, in _retry_request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1058, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 2024-10-20 23:40:15 WARNING semantic_router.utils.logger Retrying in 1 seconds due to OpenAIError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 2024-10-20 23:40:17 ERROR semantic_router.utils.logger Exception occurred
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_router/encoders/openai.py", line 117, in __call__
#     embeds = self.client.embeddings.create(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/resources/embeddings.py", line 124, in create
#     return self._post(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1277, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 954, in request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1043, in _request
#     return self._retry_request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1092, in _retry_request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1043, in _request
#     return self._retry_request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1092, in _retry_request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1058, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 2024-10-20 23:40:19 WARNING semantic_router.utils.logger Retrying in 2 seconds due to OpenAIError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 2024-10-20 23:40:20 ERROR semantic_router.utils.logger Exception occurred
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_router/encoders/openai.py", line 117, in __call__
#     embeds = self.client.embeddings.create(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/resources/embeddings.py", line 124, in create
#     return self._post(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1277, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 954, in request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1043, in _request
#     return self._retry_request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1092, in _retry_request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1043, in _request
#     return self._retry_request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1092, in _retry_request
#     return self._request(
#   File "/opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py", line 1058, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#   0%|          | 0/1 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_router/encoders/openai.py:117, in OpenAIEncoder.__call__(self, docs, truncate)
#     116 try:
# --> 117     embeds = self.client.embeddings.create(
#     118         input=docs,
#     119         model=self.name,
#     120         dimensions=self.dimensions,
#     121     )
#     122     if embeds.data:
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1274 opts = FinalRequestOptions.construct(
#    1275     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276 )
# -> 1277 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/openai/_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 chunks = chunker(docs=["The first major breakthrough in AI came with the development of symbolic reasoning in the late 1950s. Researchers like Herbert Simon and Allen Newell developed programs capable of solving algebra problems, proving theorems, and even playing chess. However, the enthusiasm was short-lived as researchers encountered the limitations of early systems. By the 1970s, funding for AI research declined due to unrealistic expectations and the inability of early AI to handle complex tasks effectively."])
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_chunkers/utils/text.py:26, in time_it.<locals>.sync_wrapper(*args, **kwargs)
#      24 def sync_wrapper(*args, **kwargs):
#      25     start_time = time.time()
# ---> 26     result = func(*args, **kwargs)  # Call the sync function directly
#      27     end_time = time.time()
#      28     logger.debug(f"{func.__name__} duration: {end_time - start_time:.2f} seconds")
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_chunkers/chunkers/statistical.py:258, in StatisticalChunker.__call__(self, docs, batch_size)
#     256 if isinstance(doc, str):
#     257     splits = self._split(doc)
# --> 258     doc_chunks = self._chunk(splits, batch_size=batch_size)
#     259     all_chunks.append(doc_chunks)
#     260 else:
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_chunkers/utils/text.py:26, in time_it.<locals>.sync_wrapper(*args, **kwargs)
#      24 def sync_wrapper(*args, **kwargs):
#      25     start_time = time.time()
# ---> 26     result = func(*args, **kwargs)  # Call the sync function directly
#      27     end_time = time.time()
#      28     logger.debug(f"{func.__name__} duration: {end_time - start_time:.2f} seconds")
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_chunkers/chunkers/statistical.py:115, in StatisticalChunker._chunk(self, splits, batch_size, enforce_max_tokens)
#     112 if last_chunk is not None:
#     113     batch_splits = last_chunk.splits + batch_splits
# --> 115 encoded_splits = self._encode_documents(batch_splits)
#     116 similarities = self._calculate_similarity_scores(encoded_splits)
#     118 if self.dynamic_threshold:
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_chunkers/utils/text.py:26, in time_it.<locals>.sync_wrapper(*args, **kwargs)
#      24 def sync_wrapper(*args, **kwargs):
#      25     start_time = time.time()
# ---> 26     result = func(*args, **kwargs)  # Call the sync function directly
#      27     end_time = time.time()
#      28     logger.debug(f"{func.__name__} duration: {end_time - start_time:.2f} seconds")
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_chunkers/chunkers/statistical.py:309, in StatisticalChunker._encode_documents(self, docs)
#     307 batch_docs = docs[i : i + max_docs_per_batch]
#     308 try:
# --> 309     batch_embeddings = self.encoder(batch_docs)
#     310     embeddings.extend(batch_embeddings)
#     311 except Exception as e:
#
# File /opt/anaconda3/envs/agent/lib/python3.9/site-packages/semantic_router/encoders/openai.py:127, in OpenAIEncoder.__call__(self, docs, truncate)
#     125 logger.error("Exception occurred", exc_info=True)
#     126 if self.max_retries != 0 and j < self.max_retries:
# --> 127     sleep(2**j)
#     128     logger.warning(
#     129         f"Retrying in {2**j} seconds due to OpenAIError: {e}"
#     130     )
#     131 else:
#
# KeyboardInterrupt:
